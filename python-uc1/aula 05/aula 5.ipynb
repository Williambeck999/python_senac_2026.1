# %%
num1=float(input("insira o número"))

# %%
num2=float(input("insira o número"))

# %%
soma = (num1+num2)
subtração = (num1-num2)
multiplicação = (num1*num2)
divisao =(num1/num2)

# %%
print (f"resultado da soma é : {soma}")
print(f"resultado da subtraçao é : {subtração}")
print(f"resultado da multiplicação é : {multiplicação}")
print (f"resultado da divisão é : {divisao}")
# Out:
# resultado da soma é : 14.0
# resultado da subtraçao é : -2.0
# resultado da multiplicação é : 48.0
# resultado da divisão é : 0.75

# %%
valor = float(input("digite o valor da compra" ))
print(f" o valor do desconto é : {valor * 0.90 : .1f}")
# Out:
#  o valor do desconto é :  40.5

# %% [markdown]
# 2

# %%
n1 = float(input("digite seu numero :"))
n2 = float(input("digite seu numero :"))
n3 = float(input("digite seu numero :"))

# %%
print(f"a sua media é {(n1+n2+n3)/3 : .1f}")
# Out:
# a sua media é  5.3

# %% [markdown]
# 3

# %%
celsius=float(input("digite o valor da temperatura em ºC :"))

# %%
f = (celsius * (9/5)) + 32

# %%
numusu1 = float(input("digite seu numero :"))

# %% [markdown]
# # laços de repetição

# %%
# exibir cabeçalho da tabela
print(" A | B | A and B") print(" ---|---|------")

# %%
fruta = ( "maca", "banana", "melao")
for fruta in fruta :
    print (fruta)
# Out:
# maca
# banana
# melao

# %%
for indice in range(5) :
 print(f"indice : {indice} - posicao : {indice + 1}")
# Out:
# indice : 0 - posicao : 1
# indice : 1 - posicao : 2
# indice : 2 - posicao : 3
# indice : 3 - posicao : 4
# indice : 4 - posicao : 5

# %%
matriz = [1 , 2 ,3 ],["a","b","c" ],{4,"d",5}

# %%
print(matriz)
# Out:
# ([1, 2, 3], ['a', 'b', 'c'], {4, 5, 'd'})

# %%
for linha in matriz :
    print("[" , end=" ")
    for elemento in linha :
     print(f"(elemento), ",end="")
    print" , end="")
    print()
    print("Fim !!")
# Out:
# [ (elemento) , ](elemento) , ](elemento) , ]
# Fim !!
# [ (elemento) , ](elemento) , ](elemento) , ]
# Fim !!
# [ (elemento) , ](elemento) , ](elemento) , ]
# Fim !!

# %%
for in range(10) :
    if == 5:
        break
    if % 2 == 0:
        continue 
    print(i)
# Out:
#   Cell In[37], line 1
#     for range(10) :
#         ^
# SyntaxError: cannot assign to function call

# %%
for i in range(3):
    print(i)
else: 
    print(" loop concluido")
# Out:
# 0
# 1
# 2
#  loop concluido

# %%
idade =int(input(" digite seu idade "))
senha = str(input(" degite sua senha "))
if idade >= 18 :
 print("acesso liberado ")
else :
 print ("idade nao permitida")
# Out:
# acesso liberado :

# %%
senha1=input(" coloque seu login")
if senha1 == codigo :
    print (" login feito")
else :
    print("login incorreto")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 senha1=input(" coloque seu login")
# ----> 2 if senha1 == (codigo) :
#       3     print (" login feito")
#       4 else :
#       5     print("login incorreto")
#
# NameError: name 'codigo' is not defined

# %%
import random
segredo = random.randint(1,10)
for i in range (3) :
    numero = int(input("digite um numero : "))
    if numero == segredo :
        print("parabens voce acertou")

# %%
nome = input("digite seu nome : ")
senha = input ("crie uma senha :")
if (len (nome) >= 3) and (len (senha) >= 6) and (senha not in ["123456" , "senha" ]) :
    print("cadastro realizado comsucesso!")
else:
    print("erro no cadrastro! tente novamente.")
# Out:
# cadastro realizado comsucesso!
