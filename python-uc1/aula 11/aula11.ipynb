# %% [markdown]
# # aula 11

# %%
# dicionario com elementos
telefones = {"alice": "1234-5678",
             "bob" : "8765-4321",
             "jose" : "9876-54321",
             "manuel": "9123-5432",
             "luis" : "1234-5673",
             "rodrigo" : "3456-7892",
             }

print(telefones)
# Out:
# {'alice': '1234-5678', 'bob': '8765-4321', 'jose': '9876-54321', 'manuel': '9123-5432', 'luis': '1234-5673', 'rodrigo': '3456-7892'}

# %%
print(telefones["jose"])
# Out:
# 9876-54321

# %%
telefones["papagaio"]="9865-1234"
telefones["luis"] = "4323-1234"

# %%
print(telefones["luis"])
# Out:
# 4323-1234

# %%
chaves = ["nome", "dt_nascimento" , "cep", "logradouro" , "bairro" , "cidade", "estado"]
valor_padrao = "N/A"
usuario = dict.fromkeys(chaves, valor_padrao)
print(usuario)
# Out:
# {'nome': 'N/A', 'dt_nascimento': 'N/A', 'cep': 'N/A', 'logradouro': 'N/A', 'bairro': 'N/A', 'cidade': 'N/A', 'estado': 'N/A'}

# %%
usuario["nome"] = input("digite seu nome :")

# %%
print(usuario["nome"])
# Out:
# luis

# %%
usuario["nome"] = input("coloque seu nome :")
usuario["dt_nascimento"] = input("digite sua data de nascimento :")
usuario["cep"] = input("digite seu cep :")
usuario["logradouro"] = input("digite seu logradouro :")
usuario[ "bairro"] = input("digite seu bairro :")
usuario["cidade"] = input("digite sua cidade :")
usuario["estado"] = input("digite seu estado : ")

# %%
print(usuario["dt_nascimento"])
# Out:
# 09/03/00

# %%
print(usuario["cep"])
# Out:
# 22003-134

# %%
print(usuario["logradouro"])
# Out:
# cidadetanana....

# %%
print(usuario)
# Out:
# {'nome': 'will', 'dt_nascimento': '09/03/00', 'cep': '123456', 'logradouro': 'rua da silva tan na na ', 'bairro': 'bingen', 'cidade': 'petropolis', 'estado': 'rj'}

# %%
for chave , valor in usuario.items():
    print(f"{chave.capitalize():.<20}:{valor.capitalize()}")
# Out:
# Nome................:Will
# Dt_nascimento.......:09/03/00
# Cep.................:123456
# Logradouro..........:Rua da silva tan na na
# Bairro..............:Bingen
# Cidade..............:Petropolis
# Estado..............:Rj

# %%
clientes = {}
clientes["12345678912"]=usuario
print(clientes)
# Out:
# {'12345678912': {'nome': 'will', 'dt_nascimento': '09/03/00', 'cep': '123456', 'logradouro': 'rua da silva tan na na ', 'bairro': 'bingen', 'cidade': 'petropolis', 'estado': 'rj'}}
