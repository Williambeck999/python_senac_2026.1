# %% [markdown]
#  # Aula 09 - Atividade 2
# 1️⃣ Cadastro de produtos

# %%
produtos = (
    ("arroz", 4.99,10),
    ("café", 6.99,4),
    ("feijão",45.99,7),
    ("leite", 25.75,10),
    ("açucar",15.65,9),
    ("oleo",12.29,5)
)
valor_produto = 0
valor_total = 0
print("lista de produtos")
for nome, preco,qnt in produtos :
    valor_produto
    print(f"{nome:.<20} R$ {preco:.2f} qnt{qt:.02d} {valor_produto:8.2f}")
    print(f"valor total da compra : R$ (valor_total:7.2f)")
# Out:
# lista de produtos
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 14
#      10 valor_total = 0
#      11 valor_produto = valor_produto + valor_produto
#      12 print("lista de produtos")
#      13 for nome, preco,qnt in produtos :
# ---> 14     print(f"{nome:.<20} R$ {preco:.2f} qnt{qt:.02d} {valor_produto:8.2f}")
#      15     print(f"valor total da compra : R$ (valor_total:7.2f)")
#
# NameError: name 'qt' is not defined

# %% [markdown]
#  # 2️⃣ Média de notas
#
# 📚 Exercício:
# Receba 4 notas de um aluno, armazene-as em uma tupla e exiba a média das notas.

# %%
notas = [7.5,6.0,4.5,9.2]
media = sum(notas) / len(notas)
print(f"Média das notas: {media:.2f}")
# Out:
# Média das notas: 6.80

# %% [markdown]
#  # 3️⃣ Verificação de números primos
#  📚 Exercício:
# Crie uma tupla com 10 números inteiros e exiba apenas os números primos.

# %% [markdown]
#  # 4️⃣ Classificação de idade
# 📚Exercício:
# Peça ao usuário 5 idades e exiba quantas pessoas são maiores de idade.

# %%
import random
idades = (18, 25, 16, 30, 14)
idades=[]
for _ in range (100):
    idades.append(random.randint(1,92)) 
    maiores = 0 
    for idade in idades :
        if idade >= 18 :
            maiores += 1

print(f"quantidade de maiores de idade : {maiores}")
# Out:
# quantidade de maiores de idade : 84

# %% [markdown]
#  # 5️⃣ Palavras com vogais
# 📚Exercício:
#
# Crie uma tupla com palavras e exiba suas vogais.

# %% [markdown]
#  # 6️⃣ Números por extenso Exercício:
# 📚Exercício:
#
# Receba um número de 0 a 9 e exiba-o por extenso.

# %% [markdown]
#  # 7️⃣ Maior e menor valor Exercício:
# Gere uma tupla com 10 números aleatórios e exiba o maior e o menor.

# %% [markdown]
#  # 8️⃣ Frequência de elementos
#
# 📚Exercício:
# Peça ao usuário 5 números e verifique quantas vezes um número escolhido aparece.

# %% [markdown]
#  # 9️⃣ Ordenação sem modificar a tupla
#
# 📚Exercício:
# Ordene uma tupla sem modificar seu conteúdo original.

# %% [markdown]
#  # 🔟 Jogo de dados
#
# 📚Exercício:
# Simule o lançamento de um dado 5 vezes e exiba quantas vezes cada número foi sorteado.
