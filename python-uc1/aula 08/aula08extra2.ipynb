# %% [markdown]
# # aula 08 funções

# %% [markdown]
# Passagem de argumento

# %%
def saudacao(display="seu nome "):
    print (f"olá, {display} !!!")

# %%
saudacao("papagaio")
# Out:
# olá, papagaio !!!

# %%
saudacao()
# Out:
# olá, seu nome  !!!

# %%
nomes = ("luis","rodrigo","papagaio")

# %%
#passagem de argumentos arbitrarios 

def saudacoes (*nomes) :
    #print(nomes)
    for nome in nomes :
        saudacao(nome)

# %%
saudacoes("luis","rodrigo","papagaio")
# Out:
# olá, luis !!!
# olá, rodrigo !!!
# olá, papagaio !!!

# %% [markdown]
# # Exercício 1: Função saudacao
# Objetivo: Imprimir uma mensagem de boas-vindas.

# %%
def saudacao() :
    print("olá , seja bem-vindo ao curso de python!")
saudacao()
# Out:
# olá , seja bem-vindo ao curso de python!

# %% [markdown]
# # Exercício 2: Função soma
# Objetivo: Somar dois números e retornar o resultado.

# %%
def soma (a,b):
    return a + b
resultado =  soma(5,7)
print(f"A soma é :", {resultado})
# Out:
# A soma é : {12}

# %% [markdown]
# # Exercício 3: Função par_ou_impar
# Objetivo: Verificar se um número é par ou ímpar.

# %%
def par_ou_impar(n):
    if n % 2 == 0 :
        return "Par"
    else :
     return "Impar"

print(f"o numero 4 é :", par_ou_impar(4))
print(f"o numero 7 é :", par_ou_impar(7))
# Out:
# o numero 4 é : Par
# o numero 7 é : Impar

# %% [markdown]
# # Exercício 4: Função fatorial
# Objetivo: Calcular o fatorial de um número inteiro não negativo.

# %%
def fatorial(n):
    if n < 0 :
        return "numero invalido como fatorial."
    elif n == 0 :
        return 1
    else :
        resultado = 1
        for i in range(1, n + 1):
            resultado *= i
    return resultado

print (f"fatorial de 5 é :", fatorial(5))
# Out:
# fatorial de 5 é : 120

# %% [markdown]
#  # Exercício 5: Função maior_elemento
# Objetivo: Retornar o maior elemento de uma lista

# %%
def maior_elemento (lista):
    return max(lista)
numeros = [3,8,1,50,7]
print ('o maior elemento é :',maior_elemento(numeros))
# Out:
# o maior elemento é : 50

# %% [markdown]
#  # Exercício 6: Função media
# Objetivo: Calcular a média aritmética dos elementos de uma lista.

# %%
def media(lista) :
    return sum(lista) / len(lista)
valores = [10,20,30,40,50,60,70]
print("a media é:", media(valores))
# Out:
# a media é: 40.0

# %% [markdown]
# # Exercício 7: Função eh_palindromo
# Objetivo: Verificar se uma palavra é um palíndromo.

# %%
def eh_palindromo(palavra):
    return palavra == palavra[::-1]
print("ana é palíndromo?", eh_palindromo("ana"))
print("python é palíndromo?", eh_palindromo("python"))
# Out:
# ana é palíndromo? True
# python é palíndromo? False

# %% [markdown]
# # exercício 8: Função contar_vogais
# Objetivo: Contar o número de vogais em uma string.

# %%
def contar_vogais (texto):
    vogais = "aeiouAEIOU"
    contador = 0
    if i in texto :
        if i in vogais :
            contador += 1
            return contador
        print("numero de vogais em 'python': ", contar_vogais("python"))

# %% [markdown]
#  # Exercício 9: Função tabuada
# Objetivo: Retornar uma lista com a tabuada de um número (de 1 a 10).

# %% [markdown]
#  # Exercício 10: Função ordenar_por_segundo
# Objetivo: Ordenar uma lista de tuplas com base no segundo elemento de cada tupla.

# %% [markdown]
# # modulos

# %%
import math

# %%
raiz = math.sqrt

# %%
print (raiz)
# Out:
# 2.0

# %%
from math import sqrt

# %%
raiz=sqrt(25)
print(raiz)
# Out:
# 5.0
